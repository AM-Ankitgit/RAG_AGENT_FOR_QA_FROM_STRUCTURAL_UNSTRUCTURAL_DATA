# %% [markdown]
# ## Reference: https://python.langchain.com/v0.1/docs/use_cases/sql/large_db/

# %%
import os
from dotenv import load_dotenv
from pyprojroot import here
from typing import List
from langchain_community.utilities import SQLDatabase

load_dotenv()

from langchain_groq import ChatGroq

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
os.environ['GROQ_API_KEY'] = os.getenv('GROQ_API_KEY')
os.getenv('GROQ_API_KEY')

ollama_model  = ChatGroq(model="llama3-8b-8192", temperature=0)#api_key="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")
# Out:
# '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'

# %%
ollama_model  = ChatGroq(model="llama3-8b-8192", temperature=0)#api_key="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")

# %%
ollama_model.invoke("what is your name").content
# Out:
# 'I don\'t have a personal name. I\'m an AI designed to assist and communicate with users, and I don\'t have a personal identity or consciousness. I exist solely to provide information and help with tasks to the best of my abilities. You can refer to me as "Assistant" or "AI" if you like!'

# %%
#here we required multiple model
